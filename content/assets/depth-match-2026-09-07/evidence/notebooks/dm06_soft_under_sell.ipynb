# %% [markdown]
# # dm06_soft_under_sell · 一档以下软匹配
#
# 公式：`A * I(Q<=D1) * max(0, 1-(D1-Q)/(0.01*D1))`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm06_soft_under_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 11   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 35   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 59   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 83   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 107  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                 record_id           short_alias         formal_column  \
# 11   dm06_soft_under_sell  dm06_soft_under_sell  dm06_soft_under_sell
# 35   dm06_soft_under_sell  dm06_soft_under_sell  dm06_soft_under_sell
# 59   dm06_soft_under_sell  dm06_soft_under_sell  dm06_soft_under_sell
# 83   dm06_soft_under_sell  dm06_soft_under_sell  dm06_soft_under_sell
# 107  dm06_soft_under_sell  dm06_soft_under_sell  dm06_soft_under_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 11         sell          2834  2825   -0.113822 -0.145368
# 35         sell          2834  2828   -0.025488 -0.072749
# 59         sell          2834  2823    0.073570  0.167359
# 83         sell          2835  2827    0.023649  0.035429
# 107        sell          2835  2830   -0.041894 -0.060622
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 11                    NaN              -0.113822                NaN
# 35                    NaN              -0.139310                NaN
# 59                    NaN              -0.065740                NaN
# 83                    NaN              -0.042091                NaN
# 107                   NaN              -0.083985                NaN
#
#      rank_ic_cumulative
# 11            -0.145368
# 35            -0.218117
# 59            -0.050758
# 83            -0.015329
# 107           -0.075951
