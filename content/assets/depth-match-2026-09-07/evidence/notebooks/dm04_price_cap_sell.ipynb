# %% [markdown]
# # dm04_price_cap_sell · 价格封顶第一档
#
# 公式：`dm01 and B1`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm04_price_cap_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 7    2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 31   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 55   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 79   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 103  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 7    dm04_price_cap_sell  dm04_price_cap_sell  dm04_price_cap_sell
# 31   dm04_price_cap_sell  dm04_price_cap_sell  dm04_price_cap_sell
# 55   dm04_price_cap_sell  dm04_price_cap_sell  dm04_price_cap_sell
# 79   dm04_price_cap_sell  dm04_price_cap_sell  dm04_price_cap_sell
# 103  dm04_price_cap_sell  dm04_price_cap_sell  dm04_price_cap_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 7          sell          2834  2825   -0.112736 -0.146572
# 31         sell          2834  2828   -0.005541 -0.050604
# 55         sell          2834  2823    0.075950  0.173782
# 79         sell          2835  2827    0.010511  0.022855
# 103        sell          2835  2830   -0.037405 -0.054397
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 7                     NaN              -0.112736                NaN
# 31                    NaN              -0.118277                NaN
# 55                    NaN              -0.042327                NaN
# 79                    NaN              -0.031816                NaN
# 103                   NaN              -0.069221                NaN
#
#      rank_ic_cumulative
# 7             -0.146572
# 31            -0.197176
# 55            -0.023394
# 79            -0.000539
# 103           -0.054935
