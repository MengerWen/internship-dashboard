# %% [markdown]
# # dm08_adaptive_repeat_buy · 相邻变数量匹配
#
# 公式：`dm01 and adjacent_marketable_dm01 and gap<=1000ms and Q!=previous_Q`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm08_adaptive_repeat_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 14   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 38   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 62   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 86   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 110  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                     record_id               short_alias  \
# 14   dm08_adaptive_repeat_buy  dm08_adaptive_repeat_buy
# 38   dm08_adaptive_repeat_buy  dm08_adaptive_repeat_buy
# 62   dm08_adaptive_repeat_buy  dm08_adaptive_repeat_buy
# 86   dm08_adaptive_repeat_buy  dm08_adaptive_repeat_buy
# 110  dm08_adaptive_repeat_buy  dm08_adaptive_repeat_buy
#
#                 formal_column aggregation  factor_count     n  pearson_ic  \
# 14   dm08_adaptive_repeat_buy         buy          2834  2825   -0.067827
# 38   dm08_adaptive_repeat_buy         buy          2834  2828   -0.048374
# 62   dm08_adaptive_repeat_buy         buy          2834  2823    0.021690
# 86   dm08_adaptive_repeat_buy         buy          2835  2827    0.028477
# 110  dm08_adaptive_repeat_buy         buy          2835  2830   -0.042943
#
#       rank_ic  pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 14  -0.081271                   NaN              -0.067827                NaN
# 38  -0.112378                   NaN              -0.116201                NaN
# 62   0.035713                   NaN              -0.094511                NaN
# 86   0.029030                   NaN              -0.066034                NaN
# 110 -0.061905                   NaN              -0.108978                NaN
#
#      rank_ic_cumulative
# 14            -0.081271
# 38            -0.193649
# 62            -0.157936
# 86            -0.128906
# 110           -0.190812
