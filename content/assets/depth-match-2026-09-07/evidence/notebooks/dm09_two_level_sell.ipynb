# %% [markdown]
# # dm09_two_level_sell · 两档累计量匹配
#
# 公式：`A and R2 and D2>0 and Q == D1+D2`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm09_two_level_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 17   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 41   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 65   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 89   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 113  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 17   dm09_two_level_sell  dm09_two_level_sell  dm09_two_level_sell
# 41   dm09_two_level_sell  dm09_two_level_sell  dm09_two_level_sell
# 65   dm09_two_level_sell  dm09_two_level_sell  dm09_two_level_sell
# 89   dm09_two_level_sell  dm09_two_level_sell  dm09_two_level_sell
# 113  dm09_two_level_sell  dm09_two_level_sell  dm09_two_level_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 17         sell          2834  2825   -0.066161 -0.093880
# 41         sell          2834  2828   -0.076177 -0.136046
# 65         sell          2834  2823    0.016072  0.030112
# 89         sell          2835  2827    0.040052  0.040272
# 113        sell          2835  2830   -0.068918 -0.090617
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 17                    NaN              -0.066161                NaN
# 41                    NaN              -0.142338                NaN
# 65                    NaN              -0.126266                NaN
# 89                    NaN              -0.086214                NaN
# 113                   NaN              -0.155132                NaN
#
#      rank_ic_cumulative
# 17            -0.093880
# 41            -0.229926
# 65            -0.199814
# 89            -0.159542
# 113           -0.250160
