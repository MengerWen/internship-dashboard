# %% [markdown]
# # dm02_confirmed_buy · 执行确认的一档匹配
#
# 公式：`dm01 and E`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm02_confirmed_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#           date                                          label  \
# 2   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 26  2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 50  2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 74  2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 98  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#              record_id         short_alias       formal_column aggregation  \
# 2   dm02_confirmed_buy  dm02_confirmed_buy  dm02_confirmed_buy         buy
# 26  dm02_confirmed_buy  dm02_confirmed_buy  dm02_confirmed_buy         buy
# 50  dm02_confirmed_buy  dm02_confirmed_buy  dm02_confirmed_buy         buy
# 74  dm02_confirmed_buy  dm02_confirmed_buy  dm02_confirmed_buy         buy
# 98  dm02_confirmed_buy  dm02_confirmed_buy  dm02_confirmed_buy         buy
#
#     factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 2           2834  2825   -0.104611 -0.130631                   NaN
# 26          2834  2828   -0.046838 -0.096915                   NaN
# 50          2834  2823    0.046988  0.113653                   NaN
# 74          2835  2827    0.048616  0.069460                   NaN
# 98          2835  2830   -0.047686 -0.063068                   NaN
#
#     pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 2               -0.104611                NaN           -0.130631
# 26              -0.151448                NaN           -0.227546
# 50              -0.104460                NaN           -0.113893
# 74              -0.055845                NaN           -0.044433
# 98              -0.103531                NaN           -0.107502
