# %% [markdown]
# # dm05_lot_floor_sell · 百股网格匹配
#
# 公式：`A and D1 >= 100 and Q == (D1 // 100) * 100`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm05_lot_floor_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 9    2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 33   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 57   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 81   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 105  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 9    dm05_lot_floor_sell  dm05_lot_floor_sell  dm05_lot_floor_sell
# 33   dm05_lot_floor_sell  dm05_lot_floor_sell  dm05_lot_floor_sell
# 57   dm05_lot_floor_sell  dm05_lot_floor_sell  dm05_lot_floor_sell
# 81   dm05_lot_floor_sell  dm05_lot_floor_sell  dm05_lot_floor_sell
# 105  dm05_lot_floor_sell  dm05_lot_floor_sell  dm05_lot_floor_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 9          sell          2834  2825   -0.113034 -0.144674
# 33         sell          2834  2828   -0.026264 -0.073710
# 57         sell          2834  2823    0.074168  0.167687
# 81         sell          2835  2827    0.023922  0.036134
# 105        sell          2835  2830   -0.041782 -0.060570
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 9                     NaN              -0.113034                NaN
# 33                    NaN              -0.139298                NaN
# 57                    NaN              -0.065130                NaN
# 81                    NaN              -0.041208                NaN
# 105                   NaN              -0.082991                NaN
#
#      rank_ic_cumulative
# 9             -0.144674
# 33            -0.218384
# 57            -0.050696
# 81            -0.014562
# 105           -0.075132
