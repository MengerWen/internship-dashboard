# %% [markdown]
# # dm09_two_level_buy · 两档累计量匹配
#
# 公式：`A and R2 and D2>0 and Q == D1+D2`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm09_two_level_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 16   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 40   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 64   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 88   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 112  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#               record_id         short_alias       formal_column aggregation  \
# 16   dm09_two_level_buy  dm09_two_level_buy  dm09_two_level_buy         buy
# 40   dm09_two_level_buy  dm09_two_level_buy  dm09_two_level_buy         buy
# 64   dm09_two_level_buy  dm09_two_level_buy  dm09_two_level_buy         buy
# 88   dm09_two_level_buy  dm09_two_level_buy  dm09_two_level_buy         buy
# 112  dm09_two_level_buy  dm09_two_level_buy  dm09_two_level_buy         buy
#
#      factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 16           2834  2825   -0.076641 -0.114393                   NaN
# 40           2834  2828   -0.020383 -0.086236                   NaN
# 64           2834  2823   -0.012649  0.014200                   NaN
# 88           2835  2827    0.038105  0.023151                   NaN
# 112          2835  2830   -0.022123 -0.067843                   NaN
#
#      pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 16               -0.076641                NaN           -0.114393
# 40               -0.097023                NaN           -0.200629
# 64               -0.109673                NaN           -0.186429
# 88               -0.071568                NaN           -0.163278
# 112              -0.093691                NaN           -0.231121
