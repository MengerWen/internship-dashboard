# %% [markdown]
# # dm02_confirmed_sell · 执行确认的一档匹配
#
# 公式：`dm01 and E`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm02_confirmed_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#           date                                          label  \
# 3   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 27  2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 51  2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 75  2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 99  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#               record_id          short_alias        formal_column aggregation  \
# 3   dm02_confirmed_sell  dm02_confirmed_sell  dm02_confirmed_sell        sell
# 27  dm02_confirmed_sell  dm02_confirmed_sell  dm02_confirmed_sell        sell
# 51  dm02_confirmed_sell  dm02_confirmed_sell  dm02_confirmed_sell        sell
# 75  dm02_confirmed_sell  dm02_confirmed_sell  dm02_confirmed_sell        sell
# 99  dm02_confirmed_sell  dm02_confirmed_sell  dm02_confirmed_sell        sell
#
#     factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 3           2834  2825   -0.114114 -0.145759                   NaN
# 27          2834  2828   -0.025306 -0.072489                   NaN
# 51          2834  2823    0.073612  0.167573                   NaN
# 75          2835  2827    0.023368  0.035455                   NaN
# 99          2835  2830   -0.041661 -0.060198                   NaN
#
#     pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 3               -0.114114                NaN           -0.145759
# 27              -0.139420                NaN           -0.218248
# 51              -0.065809                NaN           -0.050675
# 75              -0.042440                NaN           -0.015220
# 99              -0.084101                NaN           -0.075418
