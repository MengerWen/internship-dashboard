# %% [markdown]
# # dm05_lot_floor_buy · 百股网格匹配
#
# 公式：`A and D1 >= 100 and Q == (D1 // 100) * 100`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm05_lot_floor_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 8    2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 32   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 56   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 80   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 104  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#               record_id         short_alias       formal_column aggregation  \
# 8    dm05_lot_floor_buy  dm05_lot_floor_buy  dm05_lot_floor_buy         buy
# 32   dm05_lot_floor_buy  dm05_lot_floor_buy  dm05_lot_floor_buy         buy
# 56   dm05_lot_floor_buy  dm05_lot_floor_buy  dm05_lot_floor_buy         buy
# 80   dm05_lot_floor_buy  dm05_lot_floor_buy  dm05_lot_floor_buy         buy
# 104  dm05_lot_floor_buy  dm05_lot_floor_buy  dm05_lot_floor_buy         buy
#
#      factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 8            2834  2825   -0.103755 -0.130127                   NaN
# 32           2834  2828   -0.047844 -0.097900                   NaN
# 56           2834  2823    0.048390  0.113929                   NaN
# 80           2835  2827    0.049700  0.069942                   NaN
# 104          2835  2830   -0.048270 -0.063855                   NaN
#
#      pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 8                -0.103755                NaN           -0.130127
# 32               -0.151599                NaN           -0.228027
# 56               -0.103209                NaN           -0.114099
# 80               -0.053508                NaN           -0.044157
# 104              -0.101778                NaN           -0.108012
