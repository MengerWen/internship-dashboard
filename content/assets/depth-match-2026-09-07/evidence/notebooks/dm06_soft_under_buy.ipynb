# %% [markdown]
# # dm06_soft_under_buy · 一档以下软匹配
#
# 公式：`A * I(Q<=D1) * max(0, 1-(D1-Q)/(0.01*D1))`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm06_soft_under_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 10   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 34   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 58   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 82   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 106  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 10   dm06_soft_under_buy  dm06_soft_under_buy  dm06_soft_under_buy
# 34   dm06_soft_under_buy  dm06_soft_under_buy  dm06_soft_under_buy
# 58   dm06_soft_under_buy  dm06_soft_under_buy  dm06_soft_under_buy
# 82   dm06_soft_under_buy  dm06_soft_under_buy  dm06_soft_under_buy
# 106  dm06_soft_under_buy  dm06_soft_under_buy  dm06_soft_under_buy
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 10          buy          2834  2825   -0.104883 -0.130803
# 34          buy          2834  2828   -0.046954 -0.097220
# 58          buy          2834  2823    0.047609  0.114026
# 82          buy          2835  2827    0.048735  0.069618
# 106         buy          2835  2830   -0.047919 -0.063357
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 10                    NaN              -0.104883                NaN
# 34                    NaN              -0.151837                NaN
# 58                    NaN              -0.104227                NaN
# 82                    NaN              -0.055492                NaN
# 106                   NaN              -0.103411                NaN
#
#      rank_ic_cumulative
# 10            -0.130803
# 34            -0.228023
# 58            -0.113996
# 82            -0.044378
# 106           -0.107735
