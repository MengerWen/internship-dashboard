# %% [markdown]
# # dm03_price_room_buy · 价格允许第二档
#
# 公式：`dm01 and R2`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm03_price_room_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 4    2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 28   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 52   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 76   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 100  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 4    dm03_price_room_buy  dm03_price_room_buy  dm03_price_room_buy
# 28   dm03_price_room_buy  dm03_price_room_buy  dm03_price_room_buy
# 52   dm03_price_room_buy  dm03_price_room_buy  dm03_price_room_buy
# 76   dm03_price_room_buy  dm03_price_room_buy  dm03_price_room_buy
# 100  dm03_price_room_buy  dm03_price_room_buy  dm03_price_room_buy
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 4           buy          2834  2825   -0.083288 -0.094139
# 28          buy          2834  2828   -0.065271 -0.124812
# 52          buy          2834  2823    0.025976  0.077562
# 76          buy          2835  2827    0.047436  0.051239
# 100         buy          2835  2830   -0.034887 -0.063094
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 4                     NaN              -0.083288                NaN
# 28                    NaN              -0.148559                NaN
# 52                    NaN              -0.122583                NaN
# 76                    NaN              -0.075147                NaN
# 100                   NaN              -0.110034                NaN
#
#      rank_ic_cumulative
# 4             -0.094139
# 28            -0.218951
# 52            -0.141389
# 76            -0.090150
# 100           -0.153244
