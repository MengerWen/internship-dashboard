# %% [markdown]
# # dm11_recent_buy · 近期匹配
#
# 公式：`dm01 * 2**(-(09:35-t_submit)/60s)`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm11_recent_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 20   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 44   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 68   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 92   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 116  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#            record_id      short_alias    formal_column aggregation  \
# 20   dm11_recent_buy  dm11_recent_buy  dm11_recent_buy         buy
# 44   dm11_recent_buy  dm11_recent_buy  dm11_recent_buy         buy
# 68   dm11_recent_buy  dm11_recent_buy  dm11_recent_buy         buy
# 92   dm11_recent_buy  dm11_recent_buy  dm11_recent_buy         buy
# 116  dm11_recent_buy  dm11_recent_buy  dm11_recent_buy         buy
#
#      factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 20           2834  2825   -0.080664 -0.111921                   NaN
# 44           2834  2828   -0.027175 -0.081077                   NaN
# 68           2834  2823    0.063464  0.116562                   NaN
# 92           2835  2827    0.065717  0.093895                   NaN
# 116          2835  2830   -0.040484 -0.052975                   NaN
#
#      pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 20               -0.080664                NaN           -0.111921
# 44               -0.107839                NaN           -0.192998
# 68               -0.044374                NaN           -0.076435
# 92                0.021343                NaN            0.017460
# 116              -0.019141                NaN           -0.035515
