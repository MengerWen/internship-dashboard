# %% [markdown]
# # dm12_persistent_buy · 持续匹配
#
# 公式：`C/N * (-sum(p_m*log(p_m))/log(5))`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm12_persistent_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 22   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 46   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 70   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 94   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 118  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                record_id          short_alias        formal_column  \
# 22   dm12_persistent_buy  dm12_persistent_buy  dm12_persistent_buy
# 46   dm12_persistent_buy  dm12_persistent_buy  dm12_persistent_buy
# 70   dm12_persistent_buy  dm12_persistent_buy  dm12_persistent_buy
# 94   dm12_persistent_buy  dm12_persistent_buy  dm12_persistent_buy
# 118  dm12_persistent_buy  dm12_persistent_buy  dm12_persistent_buy
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 22          buy          2834  2825   -0.104691 -0.132621
# 46          buy          2834  2828   -0.052291 -0.108413
# 70          buy          2834  2823    0.043251  0.108802
# 94          buy          2835  2827    0.056717  0.073565
# 118         buy          2835  2830   -0.045012 -0.062391
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 22                    NaN              -0.104691                NaN
# 46                    NaN              -0.156981                NaN
# 70                    NaN              -0.113730                NaN
# 94                    NaN              -0.057013                NaN
# 118                   NaN              -0.102025                NaN
#
#      rank_ic_cumulative
# 22            -0.132621
# 46            -0.241034
# 70            -0.132232
# 94            -0.058667
# 118           -0.121058
