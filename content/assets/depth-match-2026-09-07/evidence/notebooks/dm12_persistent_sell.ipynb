# %% [markdown]
# # dm12_persistent_sell · 持续匹配
#
# 公式：`C/N * (-sum(p_m*log(p_m))/log(5))`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm12_persistent_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 23   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 47   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 71   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 95   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 119  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                 record_id           short_alias         formal_column  \
# 23   dm12_persistent_sell  dm12_persistent_sell  dm12_persistent_sell
# 47   dm12_persistent_sell  dm12_persistent_sell  dm12_persistent_sell
# 71   dm12_persistent_sell  dm12_persistent_sell  dm12_persistent_sell
# 95   dm12_persistent_sell  dm12_persistent_sell  dm12_persistent_sell
# 119  dm12_persistent_sell  dm12_persistent_sell  dm12_persistent_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 23         sell          2834  2825   -0.109541 -0.142173
# 47         sell          2834  2828   -0.037794 -0.088429
# 71         sell          2834  2823    0.066882  0.156238
# 95         sell          2835  2827    0.023745  0.033604
# 119        sell          2835  2830   -0.038387 -0.058734
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 23                    NaN              -0.109541                NaN
# 47                    NaN              -0.147335                NaN
# 71                    NaN              -0.080453                NaN
# 95                    NaN              -0.056709                NaN
# 119                   NaN              -0.095096                NaN
#
#      rank_ic_cumulative
# 23            -0.142173
# 47            -0.230602
# 71            -0.074365
# 95            -0.040761
# 119           -0.099495
