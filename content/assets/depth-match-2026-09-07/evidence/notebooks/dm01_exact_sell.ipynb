# %% [markdown]
# # dm01_exact_sell · 提交量精确匹配一档
#
# 公式：`A and Q == D1`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm01_exact_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#           date                                          label  \
# 1   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 25  2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 49  2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 73  2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 97  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#           record_id      short_alias    formal_column aggregation  \
# 1   dm01_exact_sell  dm01_exact_sell  dm01_exact_sell        sell
# 25  dm01_exact_sell  dm01_exact_sell  dm01_exact_sell        sell
# 49  dm01_exact_sell  dm01_exact_sell  dm01_exact_sell        sell
# 73  dm01_exact_sell  dm01_exact_sell  dm01_exact_sell        sell
# 97  dm01_exact_sell  dm01_exact_sell  dm01_exact_sell        sell
#
#     factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 1           2834  2825   -0.114069 -0.145752                   NaN
# 25          2834  2828   -0.025309 -0.072485                   NaN
# 49          2834  2823    0.073687  0.167677                   NaN
# 73          2835  2827    0.023337  0.035397                   NaN
# 97          2835  2830   -0.041730 -0.060244                   NaN
#
#     pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 1               -0.114069                NaN           -0.145752
# 25              -0.139378                NaN           -0.218237
# 49              -0.065691                NaN           -0.050560
# 73              -0.042354                NaN           -0.015163
# 97              -0.084084                NaN           -0.075407
