# %% [markdown]
# # dm11_recent_sell · 近期匹配
#
# 公式：`dm01 * 2**(-(09:35-t_submit)/60s)`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm11_recent_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 21   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 45   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 69   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 93   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 117  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#             record_id       short_alias     formal_column aggregation  \
# 21   dm11_recent_sell  dm11_recent_sell  dm11_recent_sell        sell
# 45   dm11_recent_sell  dm11_recent_sell  dm11_recent_sell        sell
# 69   dm11_recent_sell  dm11_recent_sell  dm11_recent_sell        sell
# 93   dm11_recent_sell  dm11_recent_sell  dm11_recent_sell        sell
# 117  dm11_recent_sell  dm11_recent_sell  dm11_recent_sell        sell
#
#      factor_count     n  pearson_ic   rank_ic  pearson_ic_rolling20  \
# 21           2834  2825   -0.112002 -0.148487                   NaN
# 45           2834  2828   -0.054314 -0.105036                   NaN
# 69           2834  2823    0.055985  0.136369                   NaN
# 93           2835  2827    0.033073  0.047405                   NaN
# 117          2835  2830   -0.062110 -0.079326                   NaN
#
#      pearson_ic_cumulative  rank_ic_rolling20  rank_ic_cumulative
# 21               -0.112002                NaN           -0.148487
# 45               -0.166316                NaN           -0.253523
# 69               -0.110331                NaN           -0.117154
# 93               -0.077258                NaN           -0.069749
# 117              -0.139368                NaN           -0.149075
