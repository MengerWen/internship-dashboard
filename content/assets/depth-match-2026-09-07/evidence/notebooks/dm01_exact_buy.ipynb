# %% [markdown]
# # dm01_exact_buy · 提交量精确匹配一档
#
# 公式：`A and Q == D1`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm01_exact_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#           date                                          label       record_id  \
# 0   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last  dm01_exact_buy
# 24  2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last  dm01_exact_buy
# 48  2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last  dm01_exact_buy
# 72  2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last  dm01_exact_buy
# 96  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last  dm01_exact_buy
#
#        short_alias   formal_column aggregation  factor_count     n  \
# 0   dm01_exact_buy  dm01_exact_buy         buy          2834  2825
# 24  dm01_exact_buy  dm01_exact_buy         buy          2834  2828
# 48  dm01_exact_buy  dm01_exact_buy         buy          2834  2823
# 72  dm01_exact_buy  dm01_exact_buy         buy          2835  2827
# 96  dm01_exact_buy  dm01_exact_buy         buy          2835  2830
#
#     pearson_ic   rank_ic  pearson_ic_rolling20  pearson_ic_cumulative  \
# 0    -0.104884 -0.130660                   NaN              -0.104884
# 24   -0.046899 -0.096992                   NaN              -0.151783
# 48    0.047418  0.113888                   NaN              -0.104366
# 72    0.048565  0.069418                   NaN              -0.055801
# 96   -0.047750 -0.063072                   NaN              -0.103551
#
#     rank_ic_rolling20  rank_ic_cumulative
# 0                 NaN           -0.130660
# 24                NaN           -0.227652
# 48                NaN           -0.113764
# 72                NaN           -0.044345
# 96                NaN           -0.107417
