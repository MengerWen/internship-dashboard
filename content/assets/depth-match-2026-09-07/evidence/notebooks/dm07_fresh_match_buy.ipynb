# %% [markdown]
# # dm07_fresh_match_buy · 新深度匹配
#
# 公式：`dm01 and D1_now != D1_lag and p1_now == p1_lag`。方向：buy。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm07_fresh_match_buy"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 12   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 36   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 60   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 84   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 108  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                 record_id           short_alias         formal_column  \
# 12   dm07_fresh_match_buy  dm07_fresh_match_buy  dm07_fresh_match_buy
# 36   dm07_fresh_match_buy  dm07_fresh_match_buy  dm07_fresh_match_buy
# 60   dm07_fresh_match_buy  dm07_fresh_match_buy  dm07_fresh_match_buy
# 84   dm07_fresh_match_buy  dm07_fresh_match_buy  dm07_fresh_match_buy
# 108  dm07_fresh_match_buy  dm07_fresh_match_buy  dm07_fresh_match_buy
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 12          buy          2834  2825   -0.053996 -0.081998
# 36          buy          2834  2828   -0.021689 -0.074887
# 60          buy          2834  2823    0.029985  0.079467
# 84          buy          2835  2827    0.042583  0.077486
# 108         buy          2835  2830   -0.005648 -0.015665
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 12                    NaN              -0.053996                NaN
# 36                    NaN              -0.075686                NaN
# 60                    NaN              -0.045701                NaN
# 84                    NaN              -0.003118                NaN
# 108                   NaN              -0.008766                NaN
#
#      rank_ic_cumulative
# 12            -0.081998
# 36            -0.156886
# 60            -0.077419
# 84             0.000067
# 108           -0.015598
