# %% [markdown]
# # dm07_fresh_match_sell · 新深度匹配
#
# 公式：`dm01 and D1_now != D1_lag and p1_now == p1_lag`。方向：sell。
#
# 分母：窗口内全部有效去重新订单数，双边合计。窗口：[09:30:00,09:35:00)，Asia/Shanghai。
#
# 参数：`{"quantity_grid": 100, "soft_under_tolerance": 0.01, "depth_lag_ms": 1000, "repeat_gap_ms": 1000, "excess_cancel_ms": 100, "recency_half_life_ms": 60000, "persistence_bin_ms": 60000}`。
#
# 未知订单不给分子正贡献；分母保留。N=0 或该侧有订单但全部不可判定时为 NaN；空侧为 0。
#
# 收益为同日 [09:44,09:45) VWAP / 09:35 前最后有效成交价 - 1。累计 IC 不是资金净值。

# %%
from pathlib import Path
import json
import pandas as pd
RUN_ROOT = Path("..").resolve()
RUN_ROOT = Path(RUN_ROOT)
manifest = json.loads((RUN_ROOT / "evaluation/evaluation_manifest.json").read_text(encoding="utf-8"))
assert manifest["status"] == "complete"
assert manifest["revision"] == "147ab55c38939f3754ced42576c1b82c0b2d60f0"
column = "dm07_fresh_match_sell"
daily = pd.read_parquet(RUN_ROOT / "evaluation/daily_ic.parquet")
daily = daily.loc[daily.formal_column.eq(column)].copy()
daily.head()
# Out:
#            date                                          label  \
# 13   2024-01-02  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 37   2024-01-03  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 61   2024-01-04  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 85   2024-01-05  ret_intraday_vwap_0944_0945_from_d1_0935_last
# 109  2024-01-08  ret_intraday_vwap_0944_0945_from_d1_0935_last
#
#                  record_id            short_alias          formal_column  \
# 13   dm07_fresh_match_sell  dm07_fresh_match_sell  dm07_fresh_match_sell
# 37   dm07_fresh_match_sell  dm07_fresh_match_sell  dm07_fresh_match_sell
# 61   dm07_fresh_match_sell  dm07_fresh_match_sell  dm07_fresh_match_sell
# 85   dm07_fresh_match_sell  dm07_fresh_match_sell  dm07_fresh_match_sell
# 109  dm07_fresh_match_sell  dm07_fresh_match_sell  dm07_fresh_match_sell
#
#     aggregation  factor_count     n  pearson_ic   rank_ic  \
# 13         sell          2834  2825   -0.101621 -0.128608
# 37         sell          2834  2828    0.004236 -0.015000
# 61         sell          2834  2823    0.071060  0.166650
# 85         sell          2835  2827    0.006283  0.021171
# 109        sell          2835  2830   -0.010316 -0.003539
#
#      pearson_ic_rolling20  pearson_ic_cumulative  rank_ic_rolling20  \
# 13                    NaN              -0.101621                NaN
# 37                    NaN              -0.097385                NaN
# 61                    NaN              -0.026325                NaN
# 85                    NaN              -0.020042                NaN
# 109                   NaN              -0.030358                NaN
#
#      rank_ic_cumulative
# 13            -0.128608
# 37            -0.143608
# 61             0.023043
# 85             0.044214
# 109            0.040675
